# %%
import pandas as pd
import os

# %%
def read_csv_files(folder_path):
    # Get the list of files in the folder
    files= os.listdir(folder_path)

    # Filter for csv files
    csv_files= [file for file in files if file.endswith('.csv')]

    # Create empty dict to hold future DataFrames
    dataframes={}

    # Loop through each csv and read into DataFrame
    for csv_file in csv_files:
        path= os.path.join(folder_path, csv_file)
        df_name= os.path.splitext(csv_file)[0] # Use filename for df
        dataframes[df_name]= pd.read_csv(path)
    
    return dataframes

folder_path='resources'
result=read_csv_files(folder_path)

# %%
for key in list(result.keys()):
    new_key=key +'_df'
    result[new_key]=result.pop(key)

# Now each key in the dictionary will be file_df

# %%
for key in result.keys():
    globals()[key]=result[key]

# This iterates through the results and allows 
# us to call without using result['df']

# %%
album_df.isnull().sum()
# Out:
# album_id     0
# title        0
# artist_id    0
# dtype: int64

# %%
album2_df.isnull().sum()
# Out:
# album_id     0
# title        0
# artist_id    0
# dtype: int64

# %%
artist_df.isnull().sum()
# Out:
# artist_id    0
# name         0
# dtype: int64

# %%
customer_df.isnull().sum()
# Out:
# customer_id        0
# first_name         0
# last_name          0
# company           49
# address            0
# city               0
# state             29
# country            0
# postal_code        4
# phone              1
# fax               47
# email              0
# support_rep_id     0
# dtype: int64

# %%
clean_customer_df=customer_df.dropna(how='any')

clean_customer_df
# Out:
#     customer_id first_name  last_name  \
# 0             1       Luís  Gonçalves
# 9            10    Eduardo    Martins
# 10           11  Alexandre      Rocha
# 11           12    Roberto    Almeida
# 13           14       Mark    Philips
# 14           15   Jennifer   Peterson
# 15           16      Frank     Harris
# 16           17       Jack      Smith
# 18           19        Tim      Goyer
#
#                                              company  \
# 0   Embraer - Empresa Brasileira de Aeronáutica S.A.
# 9                                   Woodstock Discos
# 10                              Banco do Brasil S.A.
# 11                                            Riotur
# 13                                             Telus
# 14                                     Rogers Canada
# 15                                       Google Inc.
# 16                             Microsoft Corporation
# 18                                        Apple Inc.
#
# ...

# %%
clean_customer_df=clean_customer_df.reset_index(drop=True)
clean_customer_df
# Out:
#    customer_id first_name  last_name  \
# 0            1       Luís  Gonçalves
# 1           10    Eduardo    Martins
# 2           11  Alexandre      Rocha
# 3           12    Roberto    Almeida
# 4           14       Mark    Philips
# 5           15   Jennifer   Peterson
# 6           16      Frank     Harris
# 7           17       Jack      Smith
# 8           19        Tim      Goyer
#
#                                             company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                  Woodstock Discos
# 2                              Banco do Brasil S.A.
# 3                                            Riotur
# 4                                             Telus
# 5                                     Rogers Canada
# 6                                       Google Inc.
# 7                             Microsoft Corporation
# 8                                        Apple Inc.
#
# ...

# %%
employee_df.isnull().sum()
# Out:
# employee_id    0
# last_name      0
# first_name     0
# title          0
# reports_to     1
# levels         0
# birthdate      0
# hire_date      0
# address        0
# city           0
# state          0
# country        0
# postal_code    0
# phone          0
# fax            0
# email          0
# dtype: int64

# %%
employee_df
# Normally I would drop null values but in this context, I keep the null.
# Since that is the most senior employee, he reports to no one.
# Out:
#    employee_id last_name first_name                   title  reports_to  \
# 0            1     Adams     Andrew         General Manager         9.0
# 1            2   Edwards      Nancy           Sales Manager         1.0
# 2            3   Peacock       Jane     Sales Support Agent         2.0
# 3            4      Park   Margaret     Sales Support Agent         2.0
# 4            5   Johnson      Steve     Sales Support Agent         2.0
# 5            6  Mitchell    Michael              IT Manager         1.0
# 6            7      King     Robert                IT Staff         6.0
# 7            8  Callahan      Laura                IT Staff         6.0
# 8            9     Madan      Mohan  Senior General Manager         NaN
#
#   levels         birthdate         hire_date                      address  \
# 0     L6  18-02-1962 00:00  14-08-2016 00:00          11120 Jasper Ave NW
# 1     L4  08-12-1958 00:00  01-05-2016 00:00                 825 8 Ave SW
# ...

# %%
# During import to postgreSQL, the date formats don't match the expected SQL format. 
# Here I am going to change the format to match
employee_df['birthdate']= pd.to_datetime(employee_df['birthdate'], format='%d-%m-%Y %H:%M').dt.strftime('%Y-%m-%d %H:%M:%S')
employee_df['hire_date']= pd.to_datetime(employee_df['hire_date'], format='%d-%m-%Y %H:%M').dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
employee_df
# Out:
#    employee_id last_name first_name                   title  reports_to  \
# 0            1     Adams     Andrew         General Manager         9.0
# 1            2   Edwards      Nancy           Sales Manager         1.0
# 2            3   Peacock       Jane     Sales Support Agent         2.0
# 3            4      Park   Margaret     Sales Support Agent         2.0
# 4            5   Johnson      Steve     Sales Support Agent         2.0
# 5            6  Mitchell    Michael              IT Manager         1.0
# 6            7      King     Robert                IT Staff         6.0
# 7            8  Callahan      Laura                IT Staff         6.0
# 8            9     Madan      Mohan  Senior General Manager         NaN
#
#   levels            birthdate            hire_date  \
# 0     L6  1962-02-18 00:00:00  2016-08-14 00:00:00
# 1     L4  1958-12-08 00:00:00  2016-05-01 00:00:00
# 2     L1  1973-08-29 00:00:00  2017-04-01 00:00:00
# ...

# %%
employee_df.to_csv('resources/clean_employee.csv', index=False)

# %%
genre_df.isnull().sum()
# Out:
# genre_id    0
# name        0
# dtype: int64

# %%
invoice_line_df.isnull().sum()
# Out:
# invoice_line_id    0
# invoice_id         0
# track_id           0
# unit_price         0
# quantity           0
# dtype: int64

# %%
invoice_df.isnull().sum()
# Out:
# invoice_id             0
# customer_id            0
# invoice_date           0
# billing_address        0
# billing_city           0
# billing_state          0
# billing_country        0
# billing_postal_code    0
# total                  0
# dtype: int64

# %%
media_type_df.isnull().sum()
# Out:
# media_type_id    0
# name             0
# dtype: int64

# %%
playlist_track_df.isnull().sum()
# Out:
# playlist_id    0
# track_id       0
# dtype: int64

# %%
playlist_df.isnull().sum()
# Out:
# playlist_id    0
# name           0
# dtype: int64

# %%
track_df.isnull().sum()
# Out:
# track_id           0
# name               0
# album_id           0
# media_type_id      0
# genre_id           0
# composer         978
# milliseconds       0
# bytes              0
# unit_price         0
# dtype: int64

# %%
clean_track_df=track_df.dropna(how='any')

clean_track_df
# Out:
#       track_id                                               name  album_id  \
# 0            1            For Those About To Rock (We Salute You)         1
# 2            3                                    Fast As a Shark         3
# 3            4                                  Restless and Wild         3
# 4            5                               Princess of the Dawn         3
# 5            6                              Put The Finger On You         1
# ...        ...                                                ...       ...
# 3497      3498  Concerto for Violin, Strings and Continuo in G...       342
# 3499      3500  String Quartet No. 12 in C Minor, D. 703 "Quar...       344
# 3500      3501               L'orfeo, Act 3, Sinfonia (Orchestra)       345
# 3501      3502  Quintet for Horn, Violin, 2 Violas, and Cello ...       346
# 3502      3503                                      Koyaanisqatsi       347
#
#       media_type_id  genre_id  \
# ...

# %%
clean_track_df=clean_track_df.reset_index(drop=True)
clean_track_df
# Out:
#       track_id                                               name  album_id  \
# 0            1            For Those About To Rock (We Salute You)         1
# 1            3                                    Fast As a Shark         3
# 2            4                                  Restless and Wild         3
# 3            5                               Princess of the Dawn         3
# 4            6                              Put The Finger On You         1
# ...        ...                                                ...       ...
# 2520      3498  Concerto for Violin, Strings and Continuo in G...       342
# 2521      3500  String Quartet No. 12 in C Minor, D. 703 "Quar...       344
# 2522      3501               L'orfeo, Act 3, Sinfonia (Orchestra)       345
# 2523      3502  Quintet for Horn, Violin, 2 Violas, and Cello ...       346
# 2524      3503                                      Koyaanisqatsi       347
#
#       media_type_id  genre_id  \
# ...

# %%
clean_customer_df.to_csv('resources/clean_customer.csv')
clean_track_df.to_csv('resources/clean_track.csv')
